# %%
import os
from glob import glob

import funnel
import yaml

# %%
files = sorted(glob(f'{funnel.config.cache_catalog_dir}/*.yml'))

data = {}
files_w_missing_assets = []
for f in files:
    with open(f) as fid:
        data[f] = yaml.safe_load(fid)

    asset = data[f]['asset']
    if not os.path.exists(asset):
        print(f'missing {asset}')
        files_w_missing_assets.append(f)

    if 'additional_coord_values' in data[f]:
        print(f)
# Out:
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.002.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.002.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.002.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.002.pO2.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.009.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.009.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.009.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.009.pO2.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.010.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.010.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.010.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.010.pO2.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.011.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.011.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.011.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.011.pO2.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.012.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.012.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.012.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.012.pO2.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.013.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.013.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.013.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.013.pO2.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.014.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.014.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.014.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.014.pO2.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.015.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.015.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.015.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.015.pO2.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.016.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.016.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.016.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.016.pO2.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.017.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.017.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.017.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.017.pO2.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.018.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.018.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.018.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.018.pO2.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.019.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.019.TEMP.drift-corrected.ann.trend.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.019.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.020.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.020.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.021.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.021.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.022.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.022.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.023.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.023.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.024.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.024.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.025.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.025.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.026.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.026.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.027.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.027.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.028.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.028.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.029.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.030.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.030.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.031.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.031.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.032.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.032.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.034.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.034.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.035.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.035.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.101.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.101.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.102.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.102.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.103.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.103.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.104.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.104.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.105.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.20C.ocn.pop.h.105.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.002.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.002.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.009.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.009.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.010.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.010.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.011.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.011.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.012.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.012.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.013.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.013.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.014.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.014.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.015.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.015.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.016.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.016.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.017.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.017.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.018.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.018.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.019.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.019.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.020.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.020.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.021.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.021.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.022.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.022.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.023.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.023.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.024.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.024.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.025.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.025.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.026.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.026.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.027.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.027.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.028.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.028.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.029.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.029.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.030.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.030.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.031.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.031.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.032.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.032.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.034.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.034.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.035.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.035.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.101.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.101.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.102.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.102.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.103.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.103.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.104.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.104.pO2.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.105.TEMP.drift-corrected.ann-ts-glb.zarr
# missing /glade/scratch/mclong/ocean-metabolism/funnel-cache/glade-cesm1-le.RCP85.ocn.pop.h.105.pO2.drift-corrected.ann-ts-glb.zarr

# %%
files_w_missing_assets
# Out:
# ['data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.002.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.002.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.002.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.002.pO2.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.009.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.009.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.009.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.009.pO2.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.010.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.010.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.010.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.010.pO2.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.011.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.011.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.011.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.011.pO2.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.012.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.012.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.012.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.012.pO2.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.013.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.013.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.013.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.013.pO2.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.014.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.014.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.014.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.014.pO2.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.015.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.015.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.015.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.015.pO2.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.016.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.016.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.016.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.016.pO2.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.017.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.017.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.017.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.017.pO2.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.018.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.018.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.018.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.018.pO2.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.019.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.019.TEMP.drift-corrected.ann.trend.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.019.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.020.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.020.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.021.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.021.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.022.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.022.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.023.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.023.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.024.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.024.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.025.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.025.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.026.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.026.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.027.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.027.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.028.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.028.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.029.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.030.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.030.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.031.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.031.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.032.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.032.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.034.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.034.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.035.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.035.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.101.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.101.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.102.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.102.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.103.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.103.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.104.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.104.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.105.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.20C.ocn.pop.h.105.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.002.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.002.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.009.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.009.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.010.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.010.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.011.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.011.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.012.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.012.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.013.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.013.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.014.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.014.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.015.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.015.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.016.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.016.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.017.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.017.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.018.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.018.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.019.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.019.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.020.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.020.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.021.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.021.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.022.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.022.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.023.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.023.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.024.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.024.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.025.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.025.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.026.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.026.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.027.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.027.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.028.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.028.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.029.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.029.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.030.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.030.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.031.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.031.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.032.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.032.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.034.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.034.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.035.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.035.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.101.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.101.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.102.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.102.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.103.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.103.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.104.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.104.pO2.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.105.TEMP.drift-corrected.ann-ts-glb.yml',
#  'data/funnel-catalog/glade-cesm1-le.RCP85.ocn.pop.h.105.pO2.drift-corrected.ann-ts-glb.yml']

# %%
for f in files_w_missing_assets:
    os.remove(f)
